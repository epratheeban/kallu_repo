# %%
import numpy as np
from datetime import datetime
import scipy.io as sio
import pandas as pd
import matplotlib.pyplot as plt

# %%
dframe = pd.read_csv('dataset.csv', sep=',',parse_dates=[0])
dframe.head()
# Out:
#           Date/Time  Electricity:Facility [kWh](Hourly)  \
# 0   01/01  01:00:00                            1.084667
# 1   01/01  02:00:00                            0.964368
# 2   01/01  03:00:00                            0.918718
# 3   01/01  04:00:00                            0.905461
# 4   01/01  05:00:00                            0.905036
#
#    Gas:Facility [kWh](Hourly)  Heating:Electricity [kWh](Hourly)  \
# 0                   13.667359                                0.0
# 1                   13.983217                                0.0
# 2                   14.154207                                0.0
# 3                   14.175250                                0.0
# 4                   14.312042                                0.0
#
#    Heating:Gas [kWh](Hourly)  Cooling:Electricity [kWh](Hourly)  \
# 0                  13.215749                                0.0
# 1                  13.625291                                0.0
# ...

# %%
dframe.tail()
# Out:
#              Date/Time  Electricity:Facility [kWh](Hourly)  \
# 8755   12/31  20:00:00                            2.213102
# 8756   12/31  21:00:00                            2.102078
# 8757   12/31  22:00:00                            1.933645
# 8758   12/31  23:00:00                            1.613978
# 8759   12/31  24:00:00                            1.299942
#
#       Gas:Facility [kWh](Hourly)  Heating:Electricity [kWh](Hourly)  \
# 8755                    9.881465                                0.0
# 8756                    9.435020                                0.0
# 8757                    9.318732                                0.0
# 8758                    9.726723                                0.0
# 8759                    9.715029                                0.0
#
#       Heating:Gas [kWh](Hourly)  Cooling:Electricity [kWh](Hourly)  \
# 8755                   8.626150                                0.0
# ...

# %%
dframe.shape
# Out:
# (8760, 14)

# %%
dframe['Date/Time'][0] # show the first row first column values ... That is the date and time.
# Out:
# ' 01/01  01:00:00'

# %% [markdown]
# ## Now parse the date and time to see some visulaisation

# %%
dframe.columns
# Out:
# Index([u'Date/Time', u'Electricity:Facility [kWh](Hourly)',
#        u'Gas:Facility [kWh](Hourly)', u'Heating:Electricity [kWh](Hourly)',
#        u'Heating:Gas [kWh](Hourly)', u'Cooling:Electricity [kWh](Hourly)',
#        u'HVACFan:Fans:Electricity [kWh](Hourly)',
#        u'Electricity:HVAC [kWh](Hourly)', u'Fans:Electricity [kWh](Hourly)',
#        u'General:InteriorLights:Electricity [kWh](Hourly)',
#        u'General:ExteriorLights:Electricity [kWh](Hourly)',
#        u'Appl:InteriorEquipment:Electricity [kWh](Hourly)',
#        u'Misc:InteriorEquipment:Electricity [kWh](Hourly)',
#        u'Water Heater:WaterSystems:Gas [kWh](Hourly) '],
#       dtype='object')

# %%
dframe.dtypes
# Out:
# Date/Time                                            object
# Electricity:Facility [kWh](Hourly)                  float64
# Gas:Facility [kWh](Hourly)                          float64
# Heating:Electricity [kWh](Hourly)                   float64
# Heating:Gas [kWh](Hourly)                           float64
# Cooling:Electricity [kWh](Hourly)                   float64
# HVACFan:Fans:Electricity [kWh](Hourly)              float64
# Electricity:HVAC [kWh](Hourly)                      float64
# Fans:Electricity [kWh](Hourly)                      float64
# General:InteriorLights:Electricity [kWh](Hourly)    float64
# General:ExteriorLights:Electricity [kWh](Hourly)    float64
# Appl:InteriorEquipment:Electricity [kWh](Hourly)    float64
# Misc:InteriorEquipment:Electricity [kWh](Hourly)    float64
# Water Heater:WaterSystems:Gas [kWh](Hourly)         float64
# dtype: object

# %%
dframe.values
# Out:
# array([[' 01/01  01:00:00', 1.08466717217171, 13.667359047946999, ...,
#         0.09294299910333616, 0.41391490558754795, 0.42310021551489],
#        [' 01/01  02:00:00', 0.964367665528504, 13.983216679062, ...,
#         0.07618584051012475, 0.38110659841928207, 0.331675961441729],
#        [' 01/01  03:00:00', 0.918718242398253, 14.154206655051999, ...,
#         0.062326543335650325, 0.37668797119123293, 0.30566076108516904],
#        ...,
#        [' 12/31  22:00:00', 1.93364461284124, 9.31873241576047, ...,
#         0.293949375651685, 0.665445260544277, 1.00905593499656],
#        [' 12/31  23:00:00', 1.61397822974013, 9.726722819678109, ...,
#         0.23417425541181602, 0.57585759349557, 0.8297497395401608],
#        [' 12/31  24:00:00', 1.29994155493186, 9.715029249263461, ...,
#         0.151455748256992, 0.50040953357662, 0.6299533128934499]], dtype=object)

# %%
dframe.describe()
# Out:
#        Electricity:Facility [kWh](Hourly)  Gas:Facility [kWh](Hourly)  \
# count                         8760.000000                 8760.000000
# mean                             1.062860                    6.280971
# std                              0.407029                    3.987707
# min                              0.430126                    0.246038
# 25%                              0.772390                    2.867830
# 50%                              0.972684                    6.320164
# 75%                              1.245517                    9.236503
# max                              2.499431                   19.156760
#
#        Heating:Electricity [kWh](Hourly)  Heating:Gas [kWh](Hourly)  \
# count                             8760.0                8760.000000
# mean                                 0.0                   5.506461
# std                                  0.0                   3.907400
# ...

# %%
dframe['Date/Time'].head()
# Out:
# 0     01/01  01:00:00
# 1     01/01  02:00:00
# 2     01/01  03:00:00
# 3     01/01  04:00:00
# 4     01/01  05:00:00
# Name: Date/Time, dtype: object

# %%
dframe['Date/Time'] = dframe['Date/Time'].map(lambda x: datetime.strptime(str(x), '%d/%m  %H:%M:%S'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-4ce0096df321> in <module>()
# ----> 1 dframe['Date/Time'] = dframe['Date/Time'].map(lambda x: datetime.strptime(str(x), '%d/%m %H:%M:%S'))
#
# c:\python27\lib\site-packages\pandas\core\series.pyc in map(self, arg, na_action)
#    2156         else:
#    2157             # arg is a function
# -> 2158             new_values = map_f(values, arg)
#    2159
#    2160         return self._constructor(new_values,
#
# pandas\_libs\src\inference.pyx in pandas._libs.lib.map_infer (pandas\_libs\lib.c:66645)()
#
# <ipython-input-12-4ce0096df321> in <lambda>(x)
# ----> 1 dframe['Date/Time'] = dframe['Date/Time'].map(lambda x: datetime.strptime(str(x), '%d/%m %H:%M:%S'))
#
# c:\python27\lib\_strptime.pyc in _strptime(data_string, format)
#     330     if not found:
# ...
